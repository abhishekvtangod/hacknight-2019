# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import math
# %matplotlib inline

# %%
df=pd.read_csv('trainms.csv')
df.head()
# Out:
#    s.no            Timestamp  Age  Gender         Country state self_employed  \
# 0     1  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1     2  2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2     3  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3     4  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4     5  2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere  ...               leave  \
# 0             No       Yes          Often  ...       Somewhat easy
# 1             No        No         Rarely  ...          Don't know
# 2             No        No         Rarely  ...  Somewhat difficult
# 3            Yes       Yes          Often  ...  Somewhat difficult
# 4             No        No          Never  ...          Don't know
#
#   mental_health_consequence phys_health_consequence     coworkers supervisor  \
# ...

# %%
df.describe()
# Out:
#               s.no          Age
# count  1000.000000  1000.000000
# mean    500.500000    30.330000
# std     288.819436    56.889837
# min       1.000000 -1726.000000
# 25%     250.750000    27.000000
# 50%     500.500000    31.000000
# 75%     750.250000    36.000000
# max    1000.000000   329.000000

# %%
df.isnull().sum()
# Out:
# s.no                           0
# Timestamp                      0
# Age                            0
# Gender                         0
# Country                        0
# state                        400
# self_employed                 18
# family_history                 0
# treatment                      0
# work_interfere               226
# no_employees                   0
# remote_work                    0
# tech_company                   0
# benefits                       0
# care_options                   0
# wellness_program               0
# seek_help                      0
# anonymity                      0
# leave                          0
# mental_health_consequence      0
# phys_health_consequence        0
# coworkers                      0
# supervisor                     0
# mental_health_interview        0
# phys_health_interview          0
# mental_vs_physical             0
# obs_consequence                0
# comments                     873
# dtype: int64

# %%
df=df.drop(['Country','state','comments'],axis=1)
df.head()
# Out:
#    s.no            Timestamp  Age  Gender self_employed family_history  \
# 0     1  2014-08-27 11:29:31   37  Female           NaN             No
# 1     2  2014-08-27 11:29:37   44       M           NaN             No
# 2     3  2014-08-27 11:29:44   32    Male           NaN             No
# 3     4  2014-08-27 11:29:46   31    Male           NaN            Yes
# 4     5  2014-08-27 11:30:22   31    Male           NaN             No
#
#   treatment work_interfere    no_employees remote_work  ...   anonymity  \
# 0       Yes          Often            6-25          No  ...         Yes
# 1        No         Rarely  More than 1000          No  ...  Don't know
# 2        No         Rarely            6-25          No  ...  Don't know
# 3       Yes          Often          26-100          No  ...          No
# 4        No          Never         100-500         Yes  ...  Don't know
#
#                 leave mental_health_consequence phys_health_consequence  \
# ...

# %%
df=df.drop(['Timestamp'],axis=1)

# %%
df=df.replace(to_replace =['no','No','N','NO'],
                 value =0)
df=df.replace(to_replace =['yes','Yes','Y','YES'],
value =1)

# %%
# df["no_employees"].unique()

# %%
df=df.replace(to_replace =['1-5'],
                 value =1)
df=df.replace(to_replace =['6-25'],
value =2)
df=df.replace(to_replace =['26-100'],
                 value =3)
df=df.replace(to_replace =['100-500'],
value =4)
df=df.replace(to_replace =['500-1000'],
                 value =5)
df=df.replace(to_replace =['More than 1000'],
value =6)

# %%
df.head()
# Out:
#    s.no  Age  Gender  self_employed  family_history  treatment work_interfere  \
# 0     1   37  Female            NaN               0          1          Often
# 1     2   44       M            NaN               0          0         Rarely
# 2     3   32    Male            NaN               0          0         Rarely
# 3     4   31    Male            NaN               1          1          Often
# 4     5   31    Male            NaN               0          0          Never
#
#    no_employees  remote_work  tech_company  ...   anonymity  \
# 0             2            0             1  ...           1
# 1             6            0             0  ...  Don't know
# 2             2            0             1  ...  Don't know
# 3             3            0             1  ...           0
# 4             4            1             1  ...  Don't know
#
#                 leave mental_health_consequence phys_health_consequence  \
# ...

# %%
df=df.replace(to_replace =["Male","male","M","m","Male-ish","maile",'Mal', 'Male ','Man'],
                 value =0)
df=df.replace(to_replace =["Female","female","F","f",'Femake','Female ','Woman','woman'],
value =1)
df=df.replace(to_replace =['Trans-female', 'Cis Female',
       'something kinda male?', 'Cis Male',  
       'non-binary',  'Make', 'Nah', 'Enby', 'fluid',
       'Genderqueer',  'Androgyne', 'Agender',
       'cis-female/femme', 'Guy (-ish) ^_^', 'male leaning androgynous',
        'Trans woman', 'msle', 'Neuter', 'Female (trans)', 'queer',
       'Female (cis)', 'Mail', 'cis male', 'A little about you'],
value =0.5)

# %%
df.head()
# Out:
#    s.no  Age  Gender  self_employed  family_history  treatment work_interfere  \
# 0     1   37     1.0            NaN               0          1          Often
# 1     2   44     0.0            NaN               0          0         Rarely
# 2     3   32     0.0            NaN               0          0         Rarely
# 3     4   31     0.0            NaN               1          1          Often
# 4     5   31     0.0            NaN               0          0          Never
#
#    no_employees  remote_work  tech_company  ...   anonymity  \
# 0             2            0             1  ...           1
# 1             6            0             0  ...  Don't know
# 2             2            0             1  ...  Don't know
# 3             3            0             1  ...           0
# 4             4            1             1  ...  Don't know
#
#                 leave mental_health_consequence phys_health_consequence  \
# ...

# %%
df["Gender"].unique()
# Out:
# array([1. , 0. , 0.5])

# %%
df.describe()
# Out:
#               s.no          Age       Gender  self_employed  family_history  \
# count  1000.000000  1000.000000  1000.000000     982.000000     1000.000000
# mean    500.500000    30.330000     0.201000       0.125255        0.381000
# std     288.819436    56.889837     0.392113       0.331176        0.485876
# min       1.000000 -1726.000000     0.000000       0.000000        0.000000
# 25%     250.750000    27.000000     0.000000       0.000000        0.000000
# 50%     500.500000    31.000000     0.000000       0.000000        0.000000
# 75%     750.250000    36.000000     0.000000       0.000000        1.000000
# max    1000.000000   329.000000     1.000000       1.000000        1.000000
#
#          treatment  no_employees  remote_work  tech_company  obs_consequence
# count  1000.000000    1000.00000   1000.00000   1000.000000       1000.00000
# mean      0.492000       3.40900      0.29400      0.832000          0.13600
# ...

# %%
df.head()
# Out:
#    s.no  Age  Gender  self_employed  family_history  treatment work_interfere  \
# 0     1   37     1.0            NaN               0          1          Often
# 1     2   44     0.0            NaN               0          0         Rarely
# 2     3   32     0.0            NaN               0          0         Rarely
# 3     4   31     0.0            NaN               1          1          Often
# 4     5   31     0.0            NaN               0          0          Never
#
#    no_employees  remote_work  tech_company  ...   anonymity  \
# 0             2            0             1  ...           1
# 1             6            0             0  ...  Don't know
# 2             2            0             1  ...  Don't know
# 3             3            0             1  ...           0
# 4             4            1             1  ...  Don't know
#
#                 leave mental_health_consequence phys_health_consequence  \
# ...

# %%
# df=df.drop(['no_employees'],axis=1)

# %%
df.describe()
# Out:
#               s.no          Age       Gender  self_employed  family_history  \
# count  1000.000000  1000.000000  1000.000000     982.000000     1000.000000
# mean    500.500000    30.330000     0.201000       0.125255        0.381000
# std     288.819436    56.889837     0.392113       0.331176        0.485876
# min       1.000000 -1726.000000     0.000000       0.000000        0.000000
# 25%     250.750000    27.000000     0.000000       0.000000        0.000000
# 50%     500.500000    31.000000     0.000000       0.000000        0.000000
# 75%     750.250000    36.000000     0.000000       0.000000        1.000000
# max    1000.000000   329.000000     1.000000       1.000000        1.000000
#
#          treatment  no_employees  remote_work  tech_company  obs_consequence
# count  1000.000000    1000.00000   1000.00000   1000.000000       1000.00000
# mean      0.492000       3.40900      0.29400      0.832000          0.13600
# ...

# %%
df=df.replace(to_replace =["Very easy"],
                 value =0)
df=df.replace(to_replace =["Somewhat easy"],
                 value =1)
df=df.replace(to_replace =["Somewhat difficult"],
                 value =2)
df=df.replace(to_replace =["Very difficult"],
                 value =3)
df=df.replace(to_replace =["Don't know","Not sure","Maybe",'Some of them'],
                 value =1.5)



df.head()
# Out:
#    s.no  Age  Gender  self_employed  family_history  treatment work_interfere  \
# 0     1   37     1.0            NaN               0          1          Often
# 1     2   44     0.0            NaN               0          0         Rarely
# 2     3   32     0.0            NaN               0          0         Rarely
# 3     4   31     0.0            NaN               1          1          Often
# 4     5   31     0.0            NaN               0          0          Never
#
#    no_employees  remote_work  tech_company  ...  anonymity  leave  \
# 0             2            0             1  ...        1.0    1.0
# 1             6            0             0  ...        1.5    1.5
# 2             2            0             1  ...        1.5    2.0
# 3             3            0             1  ...        0.0    2.0
# 4             4            1             1  ...        1.5    1.5
#
#    mental_health_consequence  phys_health_consequence  coworkers  supervisor  \
# ...

# %%
df.head()
# Out:
#    s.no  Age  Gender  self_employed  family_history  treatment work_interfere  \
# 0     1   37     1.0            NaN               0          1          Often
# 1     2   44     0.0            NaN               0          0         Rarely
# 2     3   32     0.0            NaN               0          0         Rarely
# 3     4   31     0.0            NaN               1          1          Often
# 4     5   31     0.0            NaN               0          0          Never
#
#    no_employees  remote_work  tech_company  ...  anonymity  leave  \
# 0             2            0             1  ...        1.0    1.0
# 1             6            0             0  ...        1.5    1.5
# 2             2            0             1  ...        1.5    2.0
# 3             3            0             1  ...        0.0    2.0
# 4             4            1             1  ...        1.5    1.5
#
#    mental_health_consequence  phys_health_consequence  coworkers  supervisor  \
# ...

# %%
df=df.replace(to_replace =["Never"],
                 value =0)
df=df.replace(to_replace =["NA"],
                 value =2.5)
df=df.replace(to_replace =["Often"],
                 value =3)
df=df.replace(to_replace =["Rarely"],
                 value =5)
df=df.replace(to_replace =["Sometimes"],
                 value =7)

df.describe()
# Out:
#               s.no          Age       Gender  self_employed  family_history  \
# count  1000.000000  1000.000000  1000.000000     982.000000     1000.000000
# mean    500.500000    30.330000     0.201000       0.125255        0.381000
# std     288.819436    56.889837     0.392113       0.331176        0.485876
# min       1.000000 -1726.000000     0.000000       0.000000        0.000000
# 25%     250.750000    27.000000     0.000000       0.000000        0.000000
# 50%     500.500000    31.000000     0.000000       0.000000        0.000000
# 75%     750.250000    36.000000     0.000000       0.000000        1.000000
# max    1000.000000   329.000000     1.000000       1.000000        1.000000
#
#          treatment  work_interfere  no_employees  remote_work  tech_company  \
# count  1000.000000      774.000000    1000.00000   1000.00000   1000.000000
# mean      0.492000        4.574935       3.40900      0.29400      0.832000
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      s.no  Age  Gender  self_employed  family_history  treatment  \
# 0       1   37     1.0            NaN               0          1
# 1       2   44     0.0            NaN               0          0
# 2       3   32     0.0            NaN               0          0
# 3       4   31     0.0            NaN               1          1
# 4       5   31     0.0            NaN               0          0
# ..    ...  ...     ...            ...             ...        ...
# 995   996   35     0.0            1.0               0          0
# 996   997   39     0.0            0.0               0          1
# 997   998   31     1.0            0.0               1          0
# 998   999   32     0.0            0.0               0          0
# 999  1000   27     0.0            0.0               0          0
#
#      work_interfere  no_employees  remote_work  tech_company  ...  anonymity  \
# ...

# %%
df['Age']=np.where(df['Age']<=0 , df["Age"].mean(skipna=True), df['Age'])

# %%
df.describe()
# Out:
#               s.no          Age       Gender  self_employed  family_history  \
# count  1000.000000  1000.000000  1000.000000     982.000000     1000.000000
# mean    500.500000    32.145660     0.201000       0.125255        0.381000
# std     288.819436    11.909963     0.392113       0.331176        0.485876
# min       1.000000     5.000000     0.000000       0.000000        0.000000
# 25%     250.750000    27.000000     0.000000       0.000000        0.000000
# 50%     500.500000    31.000000     0.000000       0.000000        0.000000
# 75%     750.250000    36.000000     0.000000       0.000000        1.000000
# max    1000.000000   329.000000     1.000000       1.000000        1.000000
#
#          treatment  work_interfere  no_employees  remote_work  tech_company  \
# count  1000.000000      774.000000    1000.00000   1000.00000   1000.000000
# mean      0.492000        4.574935       3.40900      0.29400      0.832000
# ...

# %%
df['Age']=np.where(df['Age']>=80 , df["Age"].mean(skipna=True), df['Age'])

# %%
df.describe()
# Out:
#               s.no          Age       Gender  self_employed  family_history  \
# count  1000.000000  1000.000000  1000.000000     982.000000     1000.000000
# mean    500.500000    31.848806     0.201000       0.125255        0.381000
# std     288.819436     7.317670     0.392113       0.331176        0.485876
# min       1.000000     5.000000     0.000000       0.000000        0.000000
# 25%     250.750000    27.000000     0.000000       0.000000        0.000000
# 50%     500.500000    31.000000     0.000000       0.000000        0.000000
# 75%     750.250000    36.000000     0.000000       0.000000        1.000000
# max    1000.000000    65.000000     1.000000       1.000000        1.000000
#
#          treatment  work_interfere  no_employees  remote_work  tech_company  \
# count  1000.000000      774.000000    1000.00000   1000.00000   1000.000000
# mean      0.492000        4.574935       3.40900      0.29400      0.832000
# ...

# %%
# df=df.drop(['no_employees'],axis=1)

# %%
df.isnull().sum()
# Out:
# s.no                           0
# Age                            0
# Gender                         0
# self_employed                 18
# family_history                 0
# treatment                      0
# work_interfere               226
# no_employees                   0
# remote_work                    0
# tech_company                   0
# benefits                       0
# care_options                   0
# wellness_program               0
# seek_help                      0
# anonymity                      0
# leave                          0
# mental_health_consequence      0
# phys_health_consequence        0
# coworkers                      0
# supervisor                     0
# mental_health_interview        0
# phys_health_interview          0
# mental_vs_physical             0
# obs_consequence                0
# dtype: int64

# %%
df=df.replace(to_replace =["NaN"],
                 value =0.3)

# %%
df.isnull().sum()
# Out:
# s.no                           0
# Age                            0
# Gender                         0
# self_employed                 18
# family_history                 0
# treatment                      0
# work_interfere               226
# no_employees                   0
# remote_work                    0
# tech_company                   0
# benefits                       0
# care_options                   0
# wellness_program               0
# seek_help                      0
# anonymity                      0
# leave                          0
# mental_health_consequence      0
# phys_health_consequence        0
# coworkers                      0
# supervisor                     0
# mental_health_interview        0
# phys_health_interview          0
# mental_vs_physical             0
# obs_consequence                0
# dtype: int64

# %%
df["self_employed"].fillna(0.7, inplace = True)
df["work_interfere"].fillna(0.2, inplace = True)

# %%
df.describe()
# Out:
#               s.no          Age       Gender  self_employed  family_history  \
# count  1000.000000  1000.000000  1000.000000    1000.000000     1000.000000
# mean    500.500000    31.848806     0.201000       0.135600        0.381000
# std     288.819436     7.317670     0.392113       0.336966        0.485876
# min       1.000000     5.000000     0.000000       0.000000        0.000000
# 25%     250.750000    27.000000     0.000000       0.000000        0.000000
# 50%     500.500000    31.000000     0.000000       0.000000        0.000000
# 75%     750.250000    36.000000     0.000000       0.000000        1.000000
# max    1000.000000    65.000000     1.000000       1.000000        1.000000
#
#          treatment  work_interfere  no_employees  remote_work  tech_company  \
# count  1000.000000     1000.000000    1000.00000   1000.00000   1000.000000
# mean      0.492000        3.586200       3.40900      0.29400      0.832000
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      s.no   Age  Gender  self_employed  family_history  treatment  \
# 0       1  37.0     1.0            0.7               0          1
# 1       2  44.0     0.0            0.7               0          0
# 2       3  32.0     0.0            0.7               0          0
# 3       4  31.0     0.0            0.7               1          1
# 4       5  31.0     0.0            0.7               0          0
# ..    ...   ...     ...            ...             ...        ...
# 995   996  35.0     0.0            1.0               0          0
# 996   997  39.0     0.0            0.0               0          1
# 997   998  31.0     1.0            0.0               1          0
# 998   999  32.0     0.0            0.0               0          0
# 999  1000  27.0     0.0            0.0               0          0
#
#      work_interfere  no_employees  remote_work  tech_company  ...  anonymity  \
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
model=LogisticRegression()
labels=df['treatment']
df_train=df.drop(['treatment'],axis=1)
x_train,x_test,y_train,y_test=train_test_split(df_train,labels,test_size=0.2)
model=RandomForestClassifier(n_estimators=10)
model.fit(x_train,y_train)
prediction=model.predict(x_test)
print(model.score(x_test,y_test))
# Out:
# 0.835

# %%
print(model.score(x_test,y_test))
# Out:
# 0.835

# %%
df1=pd.read_csv('testms.csv')
df1.head()
# Out:
#    s.no            Timestamp  Age  Gender         Country state self_employed  \
# 0     1  2014-08-29 09:29:37   25    Male   United States    PA            No
# 1     2  2014-08-29 09:31:37   42    male   United States    IN            No
# 2     3  2014-08-29 09:31:49   34    male   United States    PA            No
# 3     4  2014-08-29 09:33:43   26  female   United States    OH            No
# 4     5  2014-08-29 09:35:46   35    Male  United Kingdom   NaN            No
#
#   family_history work_interfere no_employees  ...          leave  \
# 0            Yes          Often         6-25  ...  Somewhat easy
# 1            Yes      Sometimes         6-25  ...     Don't know
# 2            Yes          Often      100-500  ...      Very easy
# 3             No      Sometimes       26-100  ...     Don't know
# 4            Yes      Sometimes          1-5  ...      Very easy
#
#   mental_health_consequence phys_health_consequence     coworkers  \
# ...

# %%
df1=df1.drop(['Country','state','comments'],axis=1)

# %%
df1=df1.drop(['Timestamp'],axis=1)

# %%
df1=df1.replace(to_replace =['no','No','N','NO'],
                 value =0)
df1=df1.replace(to_replace =['yes','Yes','Y','YES'],
value =1)

# %%
df1=df1.replace(to_replace =["Very easy"],
                 value =0)
df1=df1.replace(to_replace =["Somewhat easy"],
                 value =1)
df1=df1.replace(to_replace =["Somewhat difficult"],
                 value =2)
df1=df1.replace(to_replace =["Very difficult"],
                 value =3)
df1=df1.replace(to_replace =["Don't know","Not sure","Maybe",'Some of them'],
                 value =1.5)

# %%
df1=df1.replace(to_replace =["Never"],
                 value =0)
df1=df1.replace(to_replace =["NA"],
                 value =2.5)
df1=df1.replace(to_replace =["Often"],
                 value =3)
df1=df1.replace(to_replace =["Rarely"],
                 value =5)
df1=df1.replace(to_replace =["Sometimes"],
                 value =7)

df=df.replace(to_replace =["NaN"],
                 value =0.3)

# %%
df1=df1.replace(to_replace =["Male","male","M","m","Male-ish","maile",'Mal', 'Male ','Man','Malr'],
                 value =0)
df1=df1.replace(to_replace =["Female","female","F","f",'Femake','Female ','Woman','woman','femail'],
value =1)
df1=df1.replace(to_replace =['Trans-female', 'Cis Female',
       'something kinda male?', 'Cis Male',  
       'non-binary',  'Make', 'Nah', 'Enby', 'fluid',
       'Genderqueer',  'Androgyne', 'Agender',
       'cis-female/femme', 'Guy (-ish) ^_^', 'male leaning androgynous',
        'Trans woman', 'msle', 'Neuter', 'Female (trans)', 'queer',
       'Female (cis)', 'Mail', 'cis male', 'A little about you', 'Cis Man',
       'ostensibly male, unsure what that really means' , 'p'],
value =0.5)

# %%
df1["Gender"].unique()
# Out:
# array([0. , 1. , 0.5])

# %%
df1['Age']=np.where(df1['Age']<=0 , df1["Age"].mean(skipna=True), df1['Age'])
# df1['Age']=np.where(df1['Age']>=80 , df1["Age"].mean(skipna=True), df1['Age'])
# df1=df1.drop(['no_employees'],axis=1)
# df1.dropna()

# %%
df1["self_employed"].fillna(0.7, inplace = True)
df1["work_interfere"].fillna(0.2, inplace = True)

# %%
from sklearn.ensemble import RandomForestClassifier
X = [[0, 0], [1, 1]]
Y = [0, 1]
clf = RandomForestClassifier(n_estimators=10)
clf = clf.fit(X, Y)

# %%
df1=df1.replace(to_replace =['1-5'],
                 value =1)
df1=df1.replace(to_replace =['6-25'],
value =2)
df1=df1.replace(to_replace =['26-100'],
                 value =3)
df1=df1.replace(to_replace =['100-500'],
value =4)
df1=df1.replace(to_replace =['500-1000'],
                 value =5)
df1=df1.replace(to_replace =['More than 1000'],
value =6)

# %%
df1["Gender"].unique()
# Out:
# array([0. , 1. , 0.5])

# %%
df1["work_interfere"].values.tolist()
# Out:
# [3.0,
#  7.0,
#  3.0,
#  7.0,
#  7.0,
#  0.0,
#  7.0,
#  7.0,
#  7.0,
#  0.2,
#  0.2,
#  0.0,
#  7.0,
#  7.0,
#  7.0,
#  0.2,
#  0.2,
#  3.0,
#  7.0,
#  5.0,
#  0.0,
#  7.0,
#  0.0,
#  0.2,
#  7.0,
#  7.0,
#  0.0,
#  7.0,
#  0.0,
#  0.2,
#  0.2,
#  5.0,
#  7.0,
#  3.0,
#  0.0,
#  7.0,
#  7.0,
#  0.2,
#  7.0,
#  0.2,
#  7.0,
#  0.2,
#  7.0,
#  7.0,
#  3.0,
#  7.0,
#  7.0,
#  7.0,
#  3.0,
#  7.0,
#  7.0,
#  7.0,
#  3.0,
#  0.0,
#  5.0,
#  7.0,
#  0.0,
#  0.0,
#  3.0,
#  5.0,
#  3.0,
#  7.0,
#  0.0,
#  3.0,
#  7.0,
#  3.0,
#  0.0,
#  0.0,
#  0.0,
#  0.2,
#  7.0,
#  7.0,
#  5.0,
#  0.0,
#  7.0,
#  7.0,
#  7.0,
#  3.0,
#  7.0,
#  7.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  7.0,
#  0.2,
#  7.0,
#  0.0,
#  7.0,
#  7.0,
#  0.0,
#  0.0,
#  3.0,
#  7.0,
#  7.0,
#  7.0,
#  5.0,
#  7.0,
#  0.2,
#  0.0,
#  0.2,
#  7.0,
#  3.0,
#  7.0,
#  0.0,
#  5.0,
#  7.0,
#  5.0,
#  3.0,
#  3.0,
#  7.0,
#  3.0,
#  0.2,
#  7.0,
#  0.2,
#  7.0,
#  0.0,
#  7.0,
#  5.0,
#  0.0,
#  5.0,
#  7.0,
#  0.0,
#  5.0,
#  0.2,
# ...

# %%
Predictions=model.predict(df1)
# Predictions=Predictions.replace(to_replace =[1],value ="Yes")
# Predictions=Predictions.replace(to_replace =[0],value ="No")
df1['treatment']=Predictions
Final_Dataframe=df1[['s.no','treatment']]
Final_Dataframe=Final_Dataframe.replace({'treatment':0},{'treatment':"No"})
Final_Dataframe=Final_Dataframe.replace({'treatment':1},{'treatment':"Yes"})

Final_Dataframe.to_csv('Sub6.csv',index=False)

# %%
from sklearn.ensemble import RandomForestClassifier
X = [[0, 0], [1, 1]]
Y = [0, 1]
clf = RandomForestClassifier(n_estimators=10)
clf = clf.fit(X, Y)

# %%
from sklearn.ensemble import RandomForestClassifier
X = [[0, 0], [1, 1]]
Y = [0, 1]
clf = RandomForestClassifier(n_estimators=10)
clf = clf.fit(X, Y)

# %%
df1['treatment']=clf
Final_Dataframe=df1[['s.no','treatment']]
Final_Dataframe=Final_Dataframe.replace({'treatment':0},{'treatment':"No"})
Final_Dataframe=Final_Dataframe.replace({'treatment':1},{'treatment':"Yes"})

Final_Dataframe.to_csv('Sub6.csv',index=False)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
